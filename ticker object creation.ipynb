# %%
import pandas as pd
import yfinance as yf

# %%
ticker="AAPL"

# %%
tic=yf.Ticker(ticker)

# %%
tic
# Out:
# yfinance.Ticker object <AAPL>

# %%
listofhol=tic.get_major_holders

# %%
listofhol
# Out:
# <bound method TickerBase.get_major_holders of yfinance.Ticker object <AAPL>>

# %%
tic.history()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2020-11-25  115.550003  116.750000  115.169998  116.029999   76499200
# 2020-11-27  116.570000  117.489998  116.220001  116.589996   46691300
# 2020-11-30  116.970001  120.970001  116.809998  119.050003  169410200
# 2020-12-01  121.010002  123.470001  120.010002  122.720001  128166800
# 2020-12-02  122.019997  123.370003  120.889999  123.080002   89004200
# 2020-12-03  123.519997  123.779999  122.209999  122.940002   78967600
# 2020-12-04  122.599998  122.860001  121.519997  122.250000   78260400
# 2020-12-07  122.309998  124.570000  122.250000  123.750000   86712000
# 2020-12-08  124.370003  124.980003  123.089996  124.379997   82225500
# 2020-12-09  124.529999  125.949997  121.000000  121.779999  115089200
# 2020-12-10  120.500000  123.870003  120.150002  123.239998   81312200
# 2020-12-11  122.430000  122.760002  120.550003  122.410004   86939800
# ...

# %%
tic.get_info()
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 147000,
# ...

# %%
tic.get_major_holders()
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  59.71%       % of Shares Held by Institutions
# 2  59.75%        % of Float Held by Institutions
# 3    4479  Number of Institutions Holding Shares

# %%
tic.get_institutional_holders()
# Out:
#                                 Holder      Shares Date Reported   % Out  \
# 0           Vanguard Group, Inc. (The)  1280669129    2020-09-29  0.0753
# 1                       Blackrock Inc.  1069771045    2020-09-29  0.0629
# 2              Berkshire Hathaway, Inc   944295554    2020-09-29  0.0555
# 3             State Street Corporation   672444836    2020-09-29  0.0396
# 4                             FMR, LLC   346699497    2020-09-29  0.0204
# 5        Geode Capital Management, LLC   247838449    2020-09-29  0.0146
# 6        Price (T.Rowe) Associates Inc   228869394    2020-09-29  0.0135
# 7           Northern Trust Corporation   210830547    2020-09-29  0.0124
# 8    Norges Bank Investment Management   187425092    2019-12-30  0.0110
# 9  Bank Of New York Mellon Corporation   166053767    2020-09-29  0.0098
#
#           Value
# 0  148314291829
# 1  123890184721
# 2  109358868108
# 3   77875836457
# 4   40151268747
# 5   28702170778
# 6   26505364519
# 7   24416285648
# ...
